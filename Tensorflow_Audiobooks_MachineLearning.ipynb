# %% [markdown]
# ### Create a machine learning algorithm

# %%
import numpy as np 
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
npz = np.load(r'C:\Users\Prachi\Audioooks_data_train.npz')
train_inputs = npz['inputs'].astype(np.float) 
train_targets = npz['targets'].astype(np.int)

npz = np.load(r'C:\Users\Prachi\Audioooks_data_validation.npz')
validation_inputs = npz['inputs'].astype(np.float) 
validation_targets = npz['targets'].astype(np.int)

npz = np.load(r'C:\Users\Prachi\Audioooks_data_test.npz')
test_inputs = npz['inputs'].astype(np.float) 
test_targets = npz['targets'].astype(np.int)
# Out:
# C:\Users\Prachi\anaconda3\envs\tf2.0_env\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\Prachi\anaconda3\envs\tf2.0_env\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Prachi\anaconda3\envs\tf2.0_env\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# C:\Users\Prachi\anaconda3\envs\tf2.0_env\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys
# C:\Users\Prachi\anaconda3\envs\tf2.0_env\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Prachi\anaconda3\envs\tf2.0_env\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### MOdel
# outline, optimizers, loss, early stopping and training

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50 

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax'),
])

model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

batch_size = 100 
max_epochs = 100 

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs, 
          train_targets, 
          batch_size = batch_size, 
          epochs = max_epochs, 
          callbacks=[early_stopping],
          validation_data = (validation_inputs, validation_targets), 
          verbose=2)
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 0s - loss: 0.5822 - accuracy: 0.6709 - val_loss: 0.5236 - val_accuracy: 0.7494
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.4617 - accuracy: 0.7692 - val_loss: 0.4579 - val_accuracy: 0.7562
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.4136 - accuracy: 0.7795 - val_loss: 0.4226 - val_accuracy: 0.7673
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.3872 - accuracy: 0.7910 - val_loss: 0.4015 - val_accuracy: 0.7808
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.3695 - accuracy: 0.7988 - val_loss: 0.3856 - val_accuracy: 0.7897
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.3585 - accuracy: 0.8094 - val_loss: 0.3715 - val_accuracy: 0.8188
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.3515 - accuracy: 0.8106 - val_loss: 0.3639 - val_accuracy: 0.8188
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.3462 - accuracy: 0.8178 - val_loss: 0.3623 - val_accuracy: 0.8143
# Epoch 9/100
# 3579/3579 - 0s - loss: 0.3422 - accuracy: 0.8142 - val_loss: 0.3596 - val_accuracy: 0.8277
# Epoch 10/100
# 3579/3579 - 0s - loss: 0.3388 - accuracy: 0.8148 - val_loss: 0.3531 - val_accuracy: 0.8188
# Epoch 11/100
# 3579/3579 - 0s - loss: 0.3354 - accuracy: 0.8243 - val_loss: 0.3457 - val_accuracy: 0.8277
# Epoch 12/100
# 3579/3579 - 0s - loss: 0.3335 - accuracy: 0.8206 - val_loss: 0.3477 - val_accuracy: 0.8367
# Epoch 13/100
# 3579/3579 - 0s - loss: 0.3300 - accuracy: 0.8215 - val_loss: 0.3424 - val_accuracy: 0.8143
# Epoch 14/100
# 3579/3579 - 0s - loss: 0.3287 - accuracy: 0.8237 - val_loss: 0.3399 - val_accuracy: 0.8233
# Epoch 15/100
# 3579/3579 - 0s - loss: 0.3280 - accuracy: 0.8184 - val_loss: 0.3444 - val_accuracy: 0.8121
# Epoch 16/100
# 3579/3579 - 0s - loss: 0.3255 - accuracy: 0.8268 - val_loss: 0.3380 - val_accuracy: 0.8434
# Epoch 17/100
# 3579/3579 - 0s - loss: 0.3217 - accuracy: 0.8240 - val_loss: 0.3384 - val_accuracy: 0.8233
# Epoch 18/100
# 3579/3579 - 0s - loss: 0.3240 - accuracy: 0.8226 - val_loss: 0.3354 - val_accuracy: 0.8456
# Epoch 19/100
# 3579/3579 - 0s - loss: 0.3215 - accuracy: 0.8287 - val_loss: 0.3404 - val_accuracy: 0.8166
# Epoch 20/100
# 3579/3579 - 0s - loss: 0.3192 - accuracy: 0.8301 - val_loss: 0.3370 - val_accuracy: 0.8233

# %% [markdown]
# ### TEst the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 448/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100))
# Out:
# Test loss: 0.34. Test accuracy: 81.03%
