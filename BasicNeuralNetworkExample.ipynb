# %% [markdown]
# ## Simple Lineat Regression, Minimal example

# %% [markdown]
# ### Import the relevant libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D  #nice 3D graphs

# %% [markdown]
# ### Generate random input data to train on

# %%
observations = 1000 
xs = np.random.uniform(low=-10, high=10, size = (observations,1))
zs = np.random.uniform(-10, 10, (observations,1))    

inputs = np.column_stack((xs,zs))
print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# ### Create the targets we will aim at

# %%
noise = np.random.uniform(-1,1,(observations,1))
targets = 2*xs- 3*zs + 5 + noise
print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ### Plot the training data

# %%
targets = targets.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d') 
ax.plot(xs, zs, targets) 
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)

# %% [markdown]
# ### Initialize variables \

# %%
init_range = 0.1
weights = np.random.uniform(-init_range, init_range, size=(2,1))
biases = np.random.uniform(-init_range, init_range, size = 1) 
print(weights) 
print(biases)
# Out:
# [[-0.03391728]
#  [-0.08305102]]
# [-0.03407804]

# %% [markdown]
# ### Set a learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# ### Train the model

# %%
for i in range(100):
    outputs = np.dot(inputs,weights) + biases
    deltas = outputs -targets
    loss = np.sum(deltas**2)/2/observations
    print(loss)
    deltas_scaled = deltas/observations
    weights = weights - learning_rate * np.dot(inputs.T, deltas_scaled) 
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 0.40216228128122317
# 0.3931109545734768
# 0.38441788482983796
# 0.37606889202383353
# 0.36805035738298075
# 0.36034920117401725
# 0.35295286136740267
# 0.3458492731462938
# 0.3390268492265668
# 0.33247446095578365
# 0.32618142016027596
# 0.3201374617107268
# 0.31433272677782137
# 0.30875774675065154
# 0.3034034277916293
# 0.2982610360027402
# 0.2933221831789135
# 0.2885788131252898
# 0.2840231885160537
# 0.27964787827340887
# 0.27544574544609396
# 0.2714099355676798
# 0.2675338654756456
# 0.26381121257301093
# 0.26023590451499223
# 0.2568021093038715
# 0.2535042257759126
# 0.2503368744648164
# 0.24729488882679912
# 0.24437330681299296
# 0.24156736277541443
# 0.2388724796932977
# 0.23628426170711572
# 0.2337984869481113
# 0.23141110065163503
# 0.22911820854306536
# 0.22691607048551674
# 0.22480109437897428
# 0.22276983030090616
# 0.22081896487879263
# 0.21894531588539445
# 0.2171458270479435
# 0.2154175630627896
# 0.2137577048073689
# 0.2121635447416871
# 0.21063248249181435
# 0.20916202060818728
# 0.207749760491801
# 0.2063933984816439
# 0.2050907220969957
# 0.20383960642845528
# 0.20263801067181653
# 0.20148397479913235
# 0.20037561636154316
# 0.19931112741864979
# 0.19828877158942265
# 0.19730688121983922
# 0.19636385466262865
# 0.1954581536646832
# 0.19458830085788023
# 0.19375287734921737
# 0.19295052040633232
# 0.19217992123463046
# 0.19143982284239555
# 0.1907290179904013
# 0.1900463472226766
# 0.18939069697521665
# 0.18876099775955077
# 0.1881562224182063
# 0.18757538444922187
# 0.18701753639697852
# 0.1864817683067211
# 0.18596720624025212
# 0.18547301085037435
# 0.18499837601175836
# 0.18454252750600073
# 0.1841047217587291
# 0.18368424462669247
# 0.18328041023286054
# 0.1828925598476283
# 0.18252006081430588
# 0.1821623055171362
# 0.18181871039015987
# 0.18148871496530974
# 0.18117178095818245
# 0.18086739138999575
# 0.18057504974429872
# 0.180294279157061
# 0.18002462163881774
# 0.17976563732760303
# 0.1795169037714524
# 0.17927801523930503
# 0.17904858205917956
# 0.17882822998254655
# 0.17861659957385867
# 0.17841334562424466
# 0.17821813658840752
# 0.17803065404381346
# 0.17785059217128424
# 0.17767765725614873

# %% [markdown]
# ### Print weights and biases and see if we have worked correctly

# %%
print(weights,biases)
# Out:
# [[ 2.00119907]
#  [-2.9992045 ]] [4.95917911]

# %% [markdown]
# ### Plot last outputs vs targets

# %%
#since they are the last ones at the end of the training, they represent the final model accuracy
#The close this plot is to a 45 degree line, the closer target and output values are

# %%
plt.plot(outputs,targets)
plt.xlabel('outputs') 
plt.ylabel('targets')
plt.show()
